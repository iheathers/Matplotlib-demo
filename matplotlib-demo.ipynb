# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.1.3'

# %%
matplotlib.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
matplotlib.use('nbagg')

# %%
matplotlib.get_backend()
# Out:
# 'nbAgg'

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(facecolor=(1, 0, 0))

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure(figsize=plt.figaspect(2.0), facecolor=(1, 0, 0, .1))

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
fig =plt.figure()

# %%
ax = fig.add_subplot(111)

# %%
ax.set(xlim=[0.5, 4.5], ylim=[-2,8], title="example", ylabel="y-axis", xlabel="x-axis")
# Out:
# [(-2, 8),
#  Text(0, 0.5, 'y-axis'),
#  (0.5, 4.5),
#  Text(0.5, 0, 'x-axis'),
#  Text(0.5, 1.0, 'example')]

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.set_xlim([1, 4.5])
# Out:
# (1, 4.5)

# %%
ax.set_ylim(1, 4)
# Out:
# (1, 4)

# %%
plt.show()

# %%
fig = plt.figure()

# %%
ax = fig.add_subplot()

# %%
ax

# %%
ax.plot([1, 2, 3, 4], [10, 20, 30, 50], color='lightblue')

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.scatter([3, 4, 5, 6], [11, 22, 33, 44], c=[1, 2, 3, 4], marker='^')

# %%
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

# %%
fig

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000238C7611388>,
# ...
#       dtype=object)

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes[0,0].set(title="upperleft")
# Out:
# [Text(0.5, 1, 'upperleft')]

# %%
plt.show()

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000238C7611388>,
# ...
#       dtype=object)

# %%
axes.flat

# %%
for ax in axes.flat:
    print(ax)
# Out:
# AxesSubplot(0.125,0.53;0.352273x0.35)
# AxesSubplot(0.547727,0.53;0.352273x0.35)
# AxesSubplot(0.125,0.11;0.352273x0.35)
# AxesSubplot(0.547727,0.11;0.352273x0.35)

# %%
for ax in axes.flat:
    ax.set(xticks=[], yticks=[])

# %%
plt.show()

# %%
plt.plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c46bdb0c2447> in <module>
# ----> 1 plt.plot
#
# NameError: name 'plt' is not defined

# %%
a = [1, 2, 3]

# %%
b = [2, 3, 4, ]

# %%
zip(a,b)

# %%
zipped = list(zip(a,b))

# %%
list(zip(*zipped))
# Out:
# [(1, 2, 3), (2, 3, 4)]

# %%
lis
