# %%
import matplotlib

# %%
matplotlib.use('nbagg')

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
t = np.arange(0.0, 5.0, 0.2)

# %%
t
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8])

# %%
plt.plot(t)

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(t, t)

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(t, t, t)

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(t, t, t, t**2)

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(t, t, t, t**2, t)

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(t, t, t, t**2, t, t**3)

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(t, t, 'C1', t, t**2, t, t**3)

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(t, t, color='green', t, t**2, t, t**3)
# Out:
#   File "<ipython-input-23-8c736b52a402>", line 1
#     plt.plot(t, t, color='green', t, t**2, t, t**3)
#                                  ^
# SyntaxError: positional argument follows keyword argument
