# %%
import matplotlib

# %%
matplotlib.use('nbagg')

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
np.random.seed(1)

# %%
np.random
# Out:
# <module 'numpy.random' from 'C:\\Users\\pshre\\anaconda3\\envs\\deep-learning\\lib\\site-packages\\numpy\\random\\__init__.py'>

# %%
data1 = np.random.random((10, 10))

# %%
data1
# Out:
# array([[4.17022005e-01, 7.20324493e-01, 1.14374817e-04, 3.02332573e-01,
#         1.46755891e-01, 9.23385948e-02, 1.86260211e-01, 3.45560727e-01,
#         3.96767474e-01, 5.38816734e-01],
#        [4.19194514e-01, 6.85219500e-01, 2.04452250e-01, 8.78117436e-01,
#         2.73875932e-02, 6.70467510e-01, 4.17304802e-01, 5.58689828e-01,
#         1.40386939e-01, 1.98101489e-01],
#        [8.00744569e-01, 9.68261576e-01, 3.13424178e-01, 6.92322616e-01,
#         8.76389152e-01, 8.94606664e-01, 8.50442114e-02, 3.90547832e-02,
#         1.69830420e-01, 8.78142503e-01],
#        [9.83468338e-02, 4.21107625e-01, 9.57889530e-01, 5.33165285e-01,
#         6.91877114e-01, 3.15515631e-01, 6.86500928e-01, 8.34625672e-01,
#         1.82882773e-02, 7.50144315e-01],
#        [9.88861089e-01, 7.48165654e-01, 2.80443992e-01, 7.89279328e-01,
#         1.03226007e-01, 4.47893526e-01, 9.08595503e-01, 2.93614148e-01,
#         2.87775339e-01, 1.30028572e-01],
# ...

# %%
data2 = 2 * np.random.random((10,10))

# %%
data2
# Out:
# array([[0.6532898 , 1.0541162 , 1.7718842 , 0.71453952, 1.8170703 ,
#         1.24672023, 0.03164249, 1.85887447, 1.38179384, 1.9946457 ],
#        [0.34468102, 0.2742715 , 1.86519093, 1.39363632, 0.13200035,
#         1.51092611, 1.50775238, 1.84604907, 1.42304952, 0.24854192],
#        [0.03976027, 0.05242197, 0.05661298, 0.49242214, 1.7200559 ,
#         1.07766213, 1.10564396, 1.68406178, 0.24834663, 0.55836736],
#        [1.17151854, 1.9391915 , 1.12206044, 0.03729458, 1.60126535,
#         0.46594855, 1.61421039, 0.77572129, 1.72708371, 1.49424329],
#        [1.11248047, 0.27291045, 0.11983538, 0.24268691, 0.08910376,
#         0.21498826, 0.45141868, 1.42597796, 1.11943396, 0.02511196],
#        [0.14394856, 1.93455266, 1.13620092, 0.40658647, 0.50465149,
#         1.48765171, 0.39085896, 1.16271785, 1.94003998, 1.6936576 ],
#        [0.47969552, 0.98753943, 1.23991144, 1.6579618 , 0.31358279,
#         0.0371524 , 0.14004429, 0.97269022, 1.21265892, 1.13770287],
# ...

# %%
3 * np.random.random((10, 10))
# Out:
# array([[2.85052836e+00, 1.66995956e+00, 2.74681905e+00, 1.92469863e+00,
#         1.17002314e+00, 1.45797200e+00, 1.81293145e+00, 1.64864376e+00,
#         2.77854428e+00, 2.75620031e+00],
#        [1.18462684e+00, 2.88978759e+00, 5.21867000e-01, 3.78988558e-01,
#         4.05237474e-01, 1.51698650e+00, 6.45744158e-02, 2.84391063e+00,
#         2.48134641e+00, 4.50569422e-02],
#        [5.28588767e-01, 9.96190723e-01, 3.92990534e-01, 2.42847208e+00,
#         1.03420996e+00, 2.82032245e+00, 1.74604254e+00, 2.63649595e+00,
#         2.53420334e+00, 2.71617696e+00],
#        [1.37964080e+00, 1.63904045e+00, 2.39581077e+00, 8.57156555e-01,
#         1.47076057e+00, 1.79733092e+00, 4.65998267e-02, 1.78044422e+00,
#         1.30102905e+00, 2.42208159e+00],
#        [9.45734409e-01, 2.67866613e+00, 1.73357165e+00, 5.52030605e-01,
#         2.36378770e+00, 1.83609353e+00, 1.61727816e-01, 1.26058104e+00,
#         2.03720651e+00, 2.75580533e+00],
# ...

# %%
data3 = 3 * np.random.random((10, 10))

# %%
fig, axes = plt.subplots(ncols=3)

# %%
fig.tight_layout()

# %%
cax = fig.add_axes([0.25, 0.1, 0.55, 0.03])

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
im = axes[0].imshow(data1, cmap='gist_earth', vmin=0, vmax=3)

# %%
plt.show()

# %%
axes[1].imshow(data2, cmap='gist_earth', vmin=0, vmax=3)

# %%
plt.show()

# %%
axes[2].imshow(data3, cmap='gist_earth', vmin=0, vmax=3)

# %%
plt.show()

# %%
fig.colorbar(im, cax=cax, orientation='horizontal')

# %%
plt.show()
