# %%
import matplotlib

# %%
matplotlib.use('nbagg')

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
np.random.seed(1874)

# %%
x, y, z = np.random.normal(0, 1, (3, 100))

# %%
x
# Out:
# array([-0.0642761 ,  1.39184478,  0.92281456,  0.37986217,  0.54779761,
#         1.47401976,  0.67233777, -0.39719957,  0.65697405, -1.24904604,
#         0.0742249 , -0.07738896,  0.58714414,  0.91938539, -0.83624069,
#        -0.45838521, -0.51884218,  0.72257539, -0.87092742, -0.27242823,
#         1.76562709, -0.68602336, -1.55437975, -2.01666152,  0.28641551,
#        -1.43047622, -1.36035716,  3.02230202, -1.5592146 ,  1.48420786,
#        -0.68506737,  0.41824402,  0.33140859, -0.51823817,  0.70596637,
#        -0.10458611,  2.01106288, -1.13379822, -0.11420922,  0.8611157 ,
#        -0.51059771,  0.10893516, -0.22792482, -0.42079532,  0.4233908 ,
#        -2.41600618,  1.25548282, -0.50963185,  0.54063648,  0.38904748,
#         0.04026718, -0.7643029 , -0.80550403,  2.25528087, -0.41429797,
#        -0.36665275, -0.40530641,  1.2831103 ,  0.95974375, -0.3952573 ,
#        -1.22971622,  0.09445897, -0.39440542, -0.05037095, -1.29151354,
# ...

# %%
x.shape
# Out:
# (100,)

# %%
t = np.arctan2(y,x)

# %%
size = 50 * np.cos(2 * t)**2 + 10

# %%
fig, axes = plt.subplots(ncols = 3)

# %%
fig.tight_layout()

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes[0].scatter(x, y, marker='o', facecolor='white', edgecolor='black', s=80)

# %%
plt.show()

# %%
axes[1].scatter(x, y, s=size, marker='s', color='darkblue')

# %%
plt.show()

# %%
axes[2].scatter(x, y, c=z, s = size, cmap='gist_ncar')

# %%
plt.show()

# %%
np.random.seed(1)

# %%
x = np.arange(5)

# %%
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
y = np.random.randn(5)

# %%
y
# Out:
# array([ 1.62434536, -0.61175641, -0.52817175, -1.07296862,  0.86540763])

# %%
fig, axes = plt.subplots(ncols=2, figsize=plt.figaspect(1./2))

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="960">

# %%
vert_bars = axes[0].bar(x, y, color='lightblue', align='center')

# %%
plt.show()

# %%
horiz_bars = axes[1].barh(x, y, color='lightblue')

# %%
plt.show()

# %%
axes[0].axhline(0, color='gray')

# %%
plt.show()

# %%
axes[1].axvline(0, color='gray')

# %%
plt.show()

# %%
vert_bars
# Out:
# <BarContainer object of 5 artists>

# %%
fig, ax = plt.subplots()

# %%
vert_bars = ax.bar(x, y, color='lightblue', align='center')

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for bar, height in zip(vert_bars, y):
    if height < 0:
        bar.set(edgecolor='darkred', facecolor='salmon')

# %%
plt.show()

# %%
np.random.seed(1)

# %%
y = np.random.randn(100)

# %%
y
# Out:
# array([-1.07296428,  0.49515861, -0.9520621 , -0.51814555, -1.4614036 ,
#        -0.51634791,  0.3511169 , -0.06877046, -1.34776494,  1.47073986,
#         0.33722094,  1.00806543,  0.78522692, -0.66486777, -1.94504696,
#        -0.91542437,  1.22515585, -1.05354607,  0.81604368, -0.61240697,
#         0.39310924, -1.82391985,  1.16707517, -0.0396687 ,  0.8858258 ,
#         0.18986165,  0.7980638 , -0.10193204,  0.74335654, -1.50957268,
#        -1.08071069,  0.725474  , -0.03917826, -0.22875417, -0.17961229,
#         0.50172511, -0.59334375,  0.5103076 , -0.91579185, -0.40725204,
#         0.98495167,  1.07125243, -1.09715436,  0.83863475, -1.03918232,
#         0.73302323, -1.89881206, -1.11711069, -0.50897228, -0.16648595,
#         1.42361443,  0.90399917,  1.57546791,  1.2066079 , -0.28286355,
#        -0.26632688,  1.06897162,  0.04037143, -0.15699367, -1.33520272,
#        -0.10646012, -2.79099641, -0.45611756, -0.97989025,  0.69257435,
# ...

# %%
y
